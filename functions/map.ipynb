# %% [markdown]
# #### The map() Function in Python
# The map() function applies a given function to all items in an input list (or any other iterable) and returns a map object (an iterator). This is particularly useful for transforming data in a list comprehensively.

# %%
def square(num):
    return num**2
square(6)
# Out:
# 36

# %%
numbers=[1,2,3,4,5]
list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
## same using lambda functions
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
## map multiple iterables
number1=[1,2,4]
number2=[7,8,9]
added_number=list(map(lambda x,y : x+y,number1,number2))

# %%
print(added_number)
# Out:
# [8, 10, 13]

# %%
  
  ## map() to convert a list of strings to integers
# Use map to convert strings to integers
  
  ## use of map to convert strings to numbers ie int
str_numbers=['1','2','3','5']
int_numbers=list(map(int,str_numbers))
print(int_numbers)
# Out:
# [1, 2, 3, 5]

# %%
## to convert words in a sentence to uppercase 
words=['apple','banana','cherry']
to_uppercase=list(map(str.upper,words))
print(to_uppercase)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
## to get the name of the person from the list of dictionaries
def get_names(people):
    return people['name']

# %%
people=[
    {'name':'ankit','age':22},
    {'name':'ajay','age':47}

]

# %%
list(map(get_names,people))
# Out:
# ['ankit', 'ajay']

# %% [markdown]
# #### Conclusion
# The map() function is a powerful tool for applying transformations to iterable data structures. It can be used with regular functions, lambda functions, and even multiple iterables, providing a versatile approach to data processing in Python. By understanding and utilizing map(), you can write more efficient and readable code.
