# %% [markdown]
# #### Functions Examples

# %% [markdown]
# #### Example 1: Temperature Conversion

# %%
def temp_conversion(temp,unit):
    if(unit=='C'):
        print("to celcius conversion")
        ans=(temp*9/5)+32
        print(ans)
    elif(unit=='F'):
        ans=(temp-32)*5/9
        print(ans)
    else :
        print("none")

# %%
temp_conversion(25,'C')
temp_conversion(77,'F')
# Out:
# to celcius conversion
# 77.0
# 25.0

# %% [markdown]
# ##### Example 2: Password Strength Checker

# %%
def is_strong_password(password):
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any( char.islower()  for char in password):
        return False
    if not any( char.isupper()for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True

# %%
print(is_strong_password("WeakPwd"))
print(is_strong_password("Str0ngPwd!"))
# Out:
# False
# True

# %% [markdown]
# ##### Example 3: Calculate the Total Cost Of Items In a Shopping Cart

# %%
def total_cost(cart):
    totalprice=0
    for item in cart:
        totalprice+=item['price']*item['quantity']
    return totalprice






cart=[
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':6},
    {'name':'Orange','price':0.7,'quantity':3}

]

# %%
result=total_cost(cart)
print(result)
# Out:
# 5.8999999999999995

# %% [markdown]
# ##### Example 4: Check IF a String Is Palindrome

# %%
def is_palindrome(s):
    s=s.lower().replace(" ","")
    return s==s[::-1]

# %%
print(is_palindrome("A man a plan a canal Panama"))
print(is_palindrome("Hello"))
# Out:
# True
# False

# %% [markdown]
# ### calculate the factorial of  a number

# %%
def find_fact(num):
    res=1
    for i in range(1,num+1):
        res=res*i
        
    return res

# %%
print(find_fact(5))
# Out:
# 120

# %% [markdown]
# ### calculate the factorial of aa number using recursion

# %%
def find_fact(num):
    if num==1 :
        return 1
    return num*find_fact(num-1)

# %%
find_fact(5)
# Out:
# 120
